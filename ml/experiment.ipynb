# %% [markdown]
# # __PROJECT 1: PREDICTABILITY OF CRYPTOCURRENY__

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import read_data, series_to_supervised
from prediction import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
# read in returns of 26 conventional currencies and 11 cryptocurrencies
returns = read_data(name='returns', binary=True)
# since most of the cryptocurrencies don't have value before 2015, I only select a subset of cryptocurrencies
returns.drop(columns=['USDBUSD', 'USDBCH', 'USDADA', 'USDLINK', 'USDBNB'], inplace=True)
# the scope of this study is from 2015 to 2022
returns = returns[returns.index >= '2015-01-01']

# %%
# create a decision tree classifier
cryptos = ['USDBTC', 'USDDOGE', 'USDETH', 'USDLTC', 'USDXRP', 'USDUSDT']
clf = DecisionTreeClassifier(random_state=0)
predicted_all, predicted_part, real = binary_task(returns, 'BTC', cryptos, clf)
# Out:
# Trained successfully!

# %%
# tune hyperparameters to maximize the accuracy
criterions = ['gini', 'entropy']
max_depths = [i for i in range(5, 26, 5)]
min_sample_splits = [i for i in range(20, 101, 20)]
min_sample_leafs = [i for i in range(20, 101, 20)]

# log
log = pd.DataFrame(columns=['type', 'criterion', 'max_depth',
                            'min_sample_split', 'min_sample_leaf',
                            'TP', 'TN', 'FP', 'FN'])

# stupid method
for criterion in criterions:
    for max_depth in max_depths:
        for min_sample_split in min_sample_splits:
            for min_sample_leaf in min_sample_leafs:
                clf = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth,
                                             min_samples_split=min_sample_split,
                                             min_samples_leaf=min_sample_leaf,
                                             random_state=0)
                predicted_all, predicted_part, real = binary_task(returns, 'BTC', cryptos, clf)
                confusion = metrics.confusion_matrix(real, predicted_part)
                log = log.append({'type': 'part', 'criterion': criterion, 'max_depth': max_depth,
                                  'min_sample_split': min_sample_split, 'min_sample_leaf': min_sample_leaf,
                                  'TP': confusion[1, 1], 'TN': confusion[0, 0],
                                  'FP': confusion[0, 1], 'FN': confusion[1, 0]}, ignore_index=True)
                confusion = metrics.confusion_matrix(real, predicted_all)
                log = log.append({'type': 'all', 'criterion': criterion, 'max_depth': max_depth,
                                  'min_sample_split': min_sample_split, 'min_sample_leaf': min_sample_leaf,
                                  'TP': confusion[1, 1], 'TN': confusion[0, 0],
                                  'FP': confusion[0, 1], 'FN': confusion[1, 0]}, ignore_index=True)
                print(f'Finish tree({criterion}, {max_depth}, {min_sample_split}, {min_sample_leaf}).')
# Out:
# Trained successfully!
# Finish tree(gini, 5, 20, 20).
# Trained successfully!
# Finish tree(gini, 5, 20, 40).
# Trained successfully!
# Finish tree(gini, 5, 20, 60).
# Trained successfully!
# Finish tree(gini, 5, 20, 80).
# Trained successfully!
# Finish tree(gini, 5, 20, 100).
# Trained successfully!
# Finish tree(gini, 5, 40, 20).
# Trained successfully!
# Finish tree(gini, 5, 40, 40).
# Trained successfully!
# Finish tree(gini, 5, 40, 60).
# Trained successfully!
# Finish tree(gini, 5, 40, 80).
# Trained successfully!
# Finish tree(gini, 5, 40, 100).
# Trained successfully!
# Finish tree(gini, 5, 60, 20).
# Trained successfully!
# Finish tree(gini, 5, 60, 40).
# Trained successfully!
# Finish tree(gini, 5, 60, 60).
# Trained successfully!
# Finish tree(gini, 5, 60, 80).
# Trained successfully!
# Finish tree(gini, 5, 60, 100).
# Trained successfully!
# Finish tree(gini, 5, 80, 20).
# Trained successfully!
# Finish tree(gini, 5, 80, 40).
# Trained successfully!
# Finish tree(gini, 5, 80, 60).
# Trained successfully!
# Finish tree(gini, 5, 80, 80).
# Trained successfully!
# Finish tree(gini, 5, 80, 100).
# Trained successfully!
# Finish tree(gini, 5, 100, 20).
# Trained successfully!
# Finish tree(gini, 5, 100, 40).
# Trained successfully!
# Finish tree(gini, 5, 100, 60).
# Trained successfully!
# Finish tree(gini, 5, 100, 80).
# Trained successfully!
# Finish tree(gini, 5, 100, 100).
# Trained successfully!
# Finish tree(gini, 10, 20, 20).
# Trained successfully!
# Finish tree(gini, 10, 20, 40).
# Trained successfully!
# Finish tree(gini, 10, 20, 60).
# Trained successfully!
# Finish tree(gini, 10, 20, 80).
# Trained successfully!
# Finish tree(gini, 10, 20, 100).
# Trained successfully!
# Finish tree(gini, 10, 40, 20).
# Trained successfully!
# Finish tree(gini, 10, 40, 40).
# Trained successfully!
# Finish tree(gini, 10, 40, 60).
# Trained successfully!
# Finish tree(gini, 10, 40, 80).
# Trained successfully!
# Finish tree(gini, 10, 40, 100).
# Trained successfully!
# Finish tree(gini, 10, 60, 20).
# Trained successfully!
# Finish tree(gini, 10, 60, 40).
# Trained successfully!
# Finish tree(gini, 10, 60, 60).
# Trained successfully!
# Finish tree(gini, 10, 60, 80).
# Trained successfully!
# Finish tree(gini, 10, 60, 100).
# Trained successfully!
# Finish tree(gini, 10, 80, 20).
# Trained successfully!
# Finish tree(gini, 10, 80, 40).
# Trained successfully!
# Finish tree(gini, 10, 80, 60).
# Trained successfully!
# Finish tree(gini, 10, 80, 80).
# Trained successfully!
# Finish tree(gini, 10, 80, 100).
# Trained successfully!
# Finish tree(gini, 10, 100, 20).
# Trained successfully!
# Finish tree(gini, 10, 100, 40).
# Trained successfully!
# Finish tree(gini, 10, 100, 60).
# Trained successfully!
# Finish tree(gini, 10, 100, 80).
# Trained successfully!
# Finish tree(gini, 10, 100, 100).
# Trained successfully!
# Finish tree(gini, 15, 20, 20).
# Trained successfully!
# Finish tree(gini, 15, 20, 40).
# Trained successfully!
# Finish tree(gini, 15, 20, 60).
# Trained successfully!
# Finish tree(gini, 15, 20, 80).
# Trained successfully!
# Finish tree(gini, 15, 20, 100).
# Trained successfully!
# Finish tree(gini, 15, 40, 20).
# Trained successfully!
# Finish tree(gini, 15, 40, 40).
# Trained successfully!
# Finish tree(gini, 15, 40, 60).
# Trained successfully!
# Finish tree(gini, 15, 40, 80).
# Trained successfully!
# Finish tree(gini, 15, 40, 100).
# Trained successfully!
# Finish tree(gini, 15, 60, 20).
# Trained successfully!
# Finish tree(gini, 15, 60, 40).
# Trained successfully!
# Finish tree(gini, 15, 60, 60).
# Trained successfully!
# Finish tree(gini, 15, 60, 80).
# Trained successfully!
# Finish tree(gini, 15, 60, 100).
# Trained successfully!
# Finish tree(gini, 15, 80, 20).
# Trained successfully!
# Finish tree(gini, 15, 80, 40).
# Trained successfully!
# Finish tree(gini, 15, 80, 60).
# Trained successfully!
# Finish tree(gini, 15, 80, 80).
# Trained successfully!
# Finish tree(gini, 15, 80, 100).
# Trained successfully!
# Finish tree(gini, 15, 100, 20).
# Trained successfully!
# Finish tree(gini, 15, 100, 40).
# Trained successfully!
# Finish tree(gini, 15, 100, 60).
# Trained successfully!
# Finish tree(gini, 15, 100, 80).
# Trained successfully!
# Finish tree(gini, 15, 100, 100).
# Trained successfully!
# Finish tree(gini, 20, 20, 20).
# Trained successfully!
# Finish tree(gini, 20, 20, 40).
# Trained successfully!
# Finish tree(gini, 20, 20, 60).
# Trained successfully!
# Finish tree(gini, 20, 20, 80).
# Trained successfully!
# Finish tree(gini, 20, 20, 100).
# Trained successfully!
# Finish tree(gini, 20, 40, 20).
# Trained successfully!
# Finish tree(gini, 20, 40, 40).
# Trained successfully!
# Finish tree(gini, 20, 40, 60).
# Trained successfully!
# Finish tree(gini, 20, 40, 80).
# Trained successfully!
# Finish tree(gini, 20, 40, 100).
# Trained successfully!
# Finish tree(gini, 20, 60, 20).
# Trained successfully!
# Finish tree(gini, 20, 60, 40).
# Trained successfully!
# Finish tree(gini, 20, 60, 60).
# Trained successfully!
# Finish tree(gini, 20, 60, 80).
# Trained successfully!
# Finish tree(gini, 20, 60, 100).
# Trained successfully!
# Finish tree(gini, 20, 80, 20).
# Trained successfully!
# Finish tree(gini, 20, 80, 40).
# Trained successfully!
# Finish tree(gini, 20, 80, 60).
# Trained successfully!
# Finish tree(gini, 20, 80, 80).
# Trained successfully!
# Finish tree(gini, 20, 80, 100).
# Trained successfully!
# Finish tree(gini, 20, 100, 20).
# Trained successfully!
# Finish tree(gini, 20, 100, 40).
# Trained successfully!
# Finish tree(gini, 20, 100, 60).
# Trained successfully!
# Finish tree(gini, 20, 100, 80).
# Trained successfully!
# Finish tree(gini, 20, 100, 100).
# Trained successfully!
# Finish tree(gini, 25, 20, 20).
# Trained successfully!
# Finish tree(gini, 25, 20, 40).
# Trained successfully!
# Finish tree(gini, 25, 20, 60).
# Trained successfully!
# Finish tree(gini, 25, 20, 80).
# Trained successfully!
# Finish tree(gini, 25, 20, 100).
# Trained successfully!
# Finish tree(gini, 25, 40, 20).
# Trained successfully!
# Finish tree(gini, 25, 40, 40).
# Trained successfully!
# Finish tree(gini, 25, 40, 60).
# Trained successfully!
# Finish tree(gini, 25, 40, 80).
# Trained successfully!
# Finish tree(gini, 25, 40, 100).
# Trained successfully!
# Finish tree(gini, 25, 60, 20).
# Trained successfully!
# Finish tree(gini, 25, 60, 40).
# Trained successfully!
# Finish tree(gini, 25, 60, 60).
# Trained successfully!
# Finish tree(gini, 25, 60, 80).
# Trained successfully!
# Finish tree(gini, 25, 60, 100).
# Trained successfully!
# Finish tree(gini, 25, 80, 20).
# Trained successfully!
# Finish tree(gini, 25, 80, 40).
# Trained successfully!
# Finish tree(gini, 25, 80, 60).
# Trained successfully!
# Finish tree(gini, 25, 80, 80).
# Trained successfully!
# Finish tree(gini, 25, 80, 100).
# Trained successfully!
# Finish tree(gini, 25, 100, 20).
# Trained successfully!
# Finish tree(gini, 25, 100, 40).
# Trained successfully!
# Finish tree(gini, 25, 100, 60).
# Trained successfully!
# Finish tree(gini, 25, 100, 80).
# Trained successfully!
# Finish tree(gini, 25, 100, 100).
# Trained successfully!
# Finish tree(entropy, 5, 20, 20).
# Trained successfully!
# Finish tree(entropy, 5, 20, 40).
# Trained successfully!
# Finish tree(entropy, 5, 20, 60).
# Trained successfully!
# Finish tree(entropy, 5, 20, 80).
# Trained successfully!
# Finish tree(entropy, 5, 20, 100).
# Trained successfully!
# Finish tree(entropy, 5, 40, 20).
# Trained successfully!
# Finish tree(entropy, 5, 40, 40).
# Trained successfully!
# Finish tree(entropy, 5, 40, 60).
# Trained successfully!
# Finish tree(entropy, 5, 40, 80).
# Trained successfully!
# Finish tree(entropy, 5, 40, 100).
# Trained successfully!
# Finish tree(entropy, 5, 60, 20).
# Trained successfully!
# Finish tree(entropy, 5, 60, 40).
# Trained successfully!
# Finish tree(entropy, 5, 60, 60).
# Trained successfully!
# Finish tree(entropy, 5, 60, 80).
# Trained successfully!
# Finish tree(entropy, 5, 60, 100).
# Trained successfully!
# Finish tree(entropy, 5, 80, 20).
# Trained successfully!
# Finish tree(entropy, 5, 80, 40).
# Trained successfully!
# Finish tree(entropy, 5, 80, 60).
# Trained successfully!
# Finish tree(entropy, 5, 80, 80).
# Trained successfully!
# Finish tree(entropy, 5, 80, 100).
# Trained successfully!
# Finish tree(entropy, 5, 100, 20).
# Trained successfully!
# Finish tree(entropy, 5, 100, 40).
# Trained successfully!
# Finish tree(entropy, 5, 100, 60).
# Trained successfully!
# Finish tree(entropy, 5, 100, 80).
# Trained successfully!
# Finish tree(entropy, 5, 100, 100).
# Trained successfully!
# Finish tree(entropy, 10, 20, 20).
# Trained successfully!
# Finish tree(entropy, 10, 20, 40).
# Trained successfully!
# Finish tree(entropy, 10, 20, 60).
# Trained successfully!
# Finish tree(entropy, 10, 20, 80).
# Trained successfully!
# Finish tree(entropy, 10, 20, 100).
# Trained successfully!
# Finish tree(entropy, 10, 40, 20).
# Trained successfully!
# Finish tree(entropy, 10, 40, 40).
# Trained successfully!
# Finish tree(entropy, 10, 40, 60).
# Trained successfully!
# Finish tree(entropy, 10, 40, 80).
# Trained successfully!
# Finish tree(entropy, 10, 40, 100).
# Trained successfully!
# Finish tree(entropy, 10, 60, 20).
# Trained successfully!
# Finish tree(entropy, 10, 60, 40).
# Trained successfully!
# Finish tree(entropy, 10, 60, 60).
# Trained successfully!
# Finish tree(entropy, 10, 60, 80).
# Trained successfully!
# Finish tree(entropy, 10, 60, 100).
# Trained successfully!
# Finish tree(entropy, 10, 80, 20).
# Trained successfully!
# Finish tree(entropy, 10, 80, 40).
# Trained successfully!
# Finish tree(entropy, 10, 80, 60).
# Trained successfully!
# Finish tree(entropy, 10, 80, 80).
# Trained successfully!
# Finish tree(entropy, 10, 80, 100).
# Trained successfully!
# Finish tree(entropy, 10, 100, 20).
# Trained successfully!
# Finish tree(entropy, 10, 100, 40).
# Trained successfully!
# Finish tree(entropy, 10, 100, 60).
# Trained successfully!
# Finish tree(entropy, 10, 100, 80).
# Trained successfully!
# Finish tree(entropy, 10, 100, 100).
# Trained successfully!
# Finish tree(entropy, 15, 20, 20).
# Trained successfully!
# Finish tree(entropy, 15, 20, 40).
# Trained successfully!
# Finish tree(entropy, 15, 20, 60).
# Trained successfully!
# Finish tree(entropy, 15, 20, 80).
# Trained successfully!
# Finish tree(entropy, 15, 20, 100).
# Trained successfully!
# Finish tree(entropy, 15, 40, 20).
# Trained successfully!
# Finish tree(entropy, 15, 40, 40).
# Trained successfully!
# Finish tree(entropy, 15, 40, 60).
# Trained successfully!
# Finish tree(entropy, 15, 40, 80).
# Trained successfully!
# Finish tree(entropy, 15, 40, 100).
# Trained successfully!
# Finish tree(entropy, 15, 60, 20).
# Trained successfully!
# Finish tree(entropy, 15, 60, 40).
# Trained successfully!
# Finish tree(entropy, 15, 60, 60).
# Trained successfully!
# Finish tree(entropy, 15, 60, 80).
# Trained successfully!
# Finish tree(entropy, 15, 60, 100).
# Trained successfully!
# Finish tree(entropy, 15, 80, 20).
# Trained successfully!
# Finish tree(entropy, 15, 80, 40).
# Trained successfully!
# Finish tree(entropy, 15, 80, 60).
# Trained successfully!
# Finish tree(entropy, 15, 80, 80).
# Trained successfully!
# Finish tree(entropy, 15, 80, 100).
# Trained successfully!
# Finish tree(entropy, 15, 100, 20).
# Trained successfully!
# Finish tree(entropy, 15, 100, 40).
# Trained successfully!
# Finish tree(entropy, 15, 100, 60).
# Trained successfully!
# Finish tree(entropy, 15, 100, 80).
# Trained successfully!
# Finish tree(entropy, 15, 100, 100).
# Trained successfully!
# Finish tree(entropy, 20, 20, 20).
# Trained successfully!
# Finish tree(entropy, 20, 20, 40).
# Trained successfully!
# Finish tree(entropy, 20, 20, 60).
# Trained successfully!
# Finish tree(entropy, 20, 20, 80).
# Trained successfully!
# Finish tree(entropy, 20, 20, 100).
# Trained successfully!
# Finish tree(entropy, 20, 40, 20).
# Trained successfully!
# Finish tree(entropy, 20, 40, 40).
# Trained successfully!
# Finish tree(entropy, 20, 40, 60).
# Trained successfully!
# Finish tree(entropy, 20, 40, 80).
# Trained successfully!
# Finish tree(entropy, 20, 40, 100).
# Trained successfully!
# Finish tree(entropy, 20, 60, 20).
# Trained successfully!
# Finish tree(entropy, 20, 60, 40).
# Trained successfully!
# Finish tree(entropy, 20, 60, 60).
# Trained successfully!
# Finish tree(entropy, 20, 60, 80).
# Trained successfully!
# Finish tree(entropy, 20, 60, 100).
# Trained successfully!
# Finish tree(entropy, 20, 80, 20).
# Trained successfully!
# Finish tree(entropy, 20, 80, 40).
# Trained successfully!
# Finish tree(entropy, 20, 80, 60).
# Trained successfully!
# Finish tree(entropy, 20, 80, 80).
# Trained successfully!
# Finish tree(entropy, 20, 80, 100).
# Trained successfully!
# Finish tree(entropy, 20, 100, 20).
# Trained successfully!
# Finish tree(entropy, 20, 100, 40).
# Trained successfully!
# Finish tree(entropy, 20, 100, 60).
# Trained successfully!
# Finish tree(entropy, 20, 100, 80).
# Trained successfully!
# Finish tree(entropy, 20, 100, 100).
# Trained successfully!
# Finish tree(entropy, 25, 20, 20).
# Trained successfully!
# Finish tree(entropy, 25, 20, 40).
# Trained successfully!
# Finish tree(entropy, 25, 20, 60).
# Trained successfully!
# Finish tree(entropy, 25, 20, 80).
# Trained successfully!
# Finish tree(entropy, 25, 20, 100).
# Trained successfully!
# Finish tree(entropy, 25, 40, 20).
# Trained successfully!
# Finish tree(entropy, 25, 40, 40).
# Trained successfully!
# Finish tree(entropy, 25, 40, 60).
# Trained successfully!
# Finish tree(entropy, 25, 40, 80).
# Trained successfully!
# Finish tree(entropy, 25, 40, 100).
# Trained successfully!
# Finish tree(entropy, 25, 60, 20).
# Trained successfully!
# Finish tree(entropy, 25, 60, 40).
# Trained successfully!
# Finish tree(entropy, 25, 60, 60).
# Trained successfully!
# Finish tree(entropy, 25, 60, 80).
# Trained successfully!
# Finish tree(entropy, 25, 60, 100).
# Trained successfully!
# Finish tree(entropy, 25, 80, 20).
# Trained successfully!
# Finish tree(entropy, 25, 80, 40).
# Trained successfully!
# Finish tree(entropy, 25, 80, 60).
# Trained successfully!
# Finish tree(entropy, 25, 80, 80).
# Trained successfully!
# Finish tree(entropy, 25, 80, 100).
# Trained successfully!
# Finish tree(entropy, 25, 100, 20).
# Trained successfully!
# Finish tree(entropy, 25, 100, 40).
# Trained successfully!
# Finish tree(entropy, 25, 100, 60).
# Trained successfully!
# Finish tree(entropy, 25, 100, 80).
# Trained successfully!
# Finish tree(entropy, 25, 100, 100).

# %%
# test GRUs

# %%
log
# Out:
#      type criterion max_depth min_sample_split min_sample_leaf   TP   TN   FP  \
# 0    part      gini         5               20              20  135  248  140
# 1     all      gini         5               20              20  125  252  136
# 2    part      gini         5               20              40  136  254  134
# 3     all      gini         5               20              40  130  241  147
# 4    part      gini         5               20              60  133  267  121
# ..    ...       ...       ...              ...             ...  ...  ...  ...
# 495   all   entropy        25              100              60  126  238  150
# 496  part   entropy        25              100              80  112  284  104
# 497   all   entropy        25              100              80  126  246  142
# 498  part   entropy        25              100             100   99  289   99
# 499   all   entropy        25              100             100  124  254  134
#
#       FN
# 0    202
# 1    212
# 2    201
# 3    207
# 4    204
# ..   ...
# 495  211
# 496  225
# 497  211
# 498  238
# 499  213
#
# [500 rows x 9 columns]

# %%
metrics.precision_score(real, predicted_part)
# Out:
# 0.4727272727272727

# %%
plt.style.use("seaborn-white")
plt.figure(figsize=(10, 8))
plt.plot(np.arange(1827,1827 + len([list(item[0])[0] for item in test_y])), [list(item[0])[0] for item in test_y], color='black')
# plt.plot(np.arange(366,1087), 1/BTC_part_, color='blue')
plt.plot(np.arange(1827,1827 + len([list(item[0])[0] for item in test_y])), predicted_all, color='red')
plt.show()
